# %% [markdown]
# **Police Dataset**
#
# Here,
#
# The data from a Police Check Point is given
# This data is available as a csv file. We are going to analyze this data set using the Pandas DataFrame

# %%
import pandas as pd

# %%
data = pd.read_csv('/content/3. Police Data.csv')
data
# Out:
#        stop_date stop_time  country_name driver_gender  driver_age_raw  \
# 0       1/2/2005      1:55           NaN             M          1985.0
# 1      1/18/2005      8:15           NaN             M          1965.0
# 2      1/23/2005     23:15           NaN             M          1972.0
# 3      2/20/2005     17:15           NaN             M          1986.0
# 4      3/14/2005     10:00           NaN             F          1984.0
# ...          ...       ...           ...           ...             ...
# 55736  1/18/2012     10:05           NaN             M          1952.0
# 55737  1/18/2012     10:12           NaN             M          1955.0
# 55738  1/18/2012     10:24           NaN             M          1983.0
# 55739  1/18/2012     10:36           NaN             F          1982.0
# 55740  1/18/2012     10:48           NaN             M          1986.0
#
#        driver_age driver_race                   violation_raw  \
# ...

# %% [markdown]
# **Instruction (For data cleaning)**
#
# **1. Remove the column that only contains missing values**

# %%
data.isnull().sum()
# Out:
# stop_date                 0
# stop_time                 0
# country_name          55741
# driver_gender          3550
# driver_age_raw         3543
# driver_age             3788
# driver_race            3549
# violation_raw          3549
# violation              3550
# search_conducted          1
# search_type           53572
# stop_outcome           3550
# is_arrested            3550
# stop_duration          3550
# drugs_related_stop        1
# dtype: int64

# %%
data.drop( columns = 'country_name' , inplace = True)

# %%
data
# Out:
#        stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0       1/2/2005      1:55             M          1985.0        20.0
# 1      1/18/2005      8:15             M          1965.0        40.0
# 2      1/23/2005     23:15             M          1972.0        33.0
# 3      2/20/2005     17:15             M          1986.0        19.0
# 4      3/14/2005     10:00             F          1984.0        21.0
# ...          ...       ...           ...             ...         ...
# 55736  1/18/2012     10:05             M          1952.0        60.0
# 55737  1/18/2012     10:12             M          1955.0        57.0
# 55738  1/18/2012     10:24             M          1983.0        29.0
# 55739  1/18/2012     10:36             F          1982.0        30.0
# 55740  1/18/2012     10:48             M          1986.0        26.0
#
#       driver_race                   violation_raw         violation  \
# 0           White                        Speeding          Speeding
# ...

# %% [markdown]
# **Question ( Based on filtering + Value Counts )**
#
# **2. For Speeding , were Men or Woman stopped more often ?**

# %%
data.head()
# Out:
#    stop_date stop_time driver_gender  driver_age_raw  driver_age driver_race  \
# 0   1/2/2005      1:55             M          1985.0        20.0       White
# 1  1/18/2005      8:15             M          1965.0        40.0       White
# 2  1/23/2005     23:15             M          1972.0        33.0       White
# 3  2/20/2005     17:15             M          1986.0        19.0       White
# 4  3/14/2005     10:00             F          1984.0        21.0       White
#
#       violation_raw violation search_conducted search_type   stop_outcome  \
# 0          Speeding  Speeding            False         NaN       Citation
# 1          Speeding  Speeding            False         NaN       Citation
# 2          Speeding  Speeding            False         NaN       Citation
# 3  Call for Service     Other            False         NaN  Arrest Driver
# 4          Speeding  Speeding            False         NaN       Citation
#
#   is_arrested stop_duration drugs_related_stop
# ...

# %%
data[data.violation == 'Speeding'].driver_gender.value_counts()
# Out:
# M    22985
# F    10306
# Name: driver_gender, dtype: int64

# %% [markdown]
# **Question ( Groupby )**
#
# **3. Does gender affect who gets searched during a stop ?**

# %%
data.head()
# Out:
#    stop_date stop_time driver_gender  driver_age_raw  driver_age driver_race  \
# 0   1/2/2005      1:55             M          1985.0        20.0       White
# 1  1/18/2005      8:15             M          1965.0        40.0       White
# 2  1/23/2005     23:15             M          1972.0        33.0       White
# 3  2/20/2005     17:15             M          1986.0        19.0       White
# 4  3/14/2005     10:00             F          1984.0        21.0       White
#
#       violation_raw violation search_conducted search_type   stop_outcome  \
# 0          Speeding  Speeding            False         NaN       Citation
# 1          Speeding  Speeding            False         NaN       Citation
# 2          Speeding  Speeding            False         NaN       Citation
# 3  Call for Service     Other            False         NaN  Arrest Driver
# 4          Speeding  Speeding            False         NaN       Citation
#
#   is_arrested stop_duration drugs_related_stop
# ...

# %%
data.groupby('driver_gender').search_conducted.sum()
# Out:
# driver_gender
# F     319
# M    1850
# Name: search_conducted, dtype: object

# %%
data.search_conducted.value_counts()
# Out:
# False    53571
# True      2169
# Name: search_conducted, dtype: int64

# %% [markdown]
# **Question ( mapping + data-type casting )**
#
# **4. What is the mean stop_duration ?**

# %%
data.head()
# Out:
#    stop_date stop_time driver_gender  driver_age_raw  driver_age driver_race  \
# 0   1/2/2005      1:55             M          1985.0        20.0       White
# 1  1/18/2005      8:15             M          1965.0        40.0       White
# 2  1/23/2005     23:15             M          1972.0        33.0       White
# 3  2/20/2005     17:15             M          1986.0        19.0       White
# 4  3/14/2005     10:00             F          1984.0        21.0       White
#
#       violation_raw violation search_conducted search_type   stop_outcome  \
# 0          Speeding  Speeding            False         NaN       Citation
# 1          Speeding  Speeding            False         NaN       Citation
# 2          Speeding  Speeding            False         NaN       Citation
# 3  Call for Service     Other            False         NaN  Arrest Driver
# 4          Speeding  Speeding            False         NaN       Citation
#
#   is_arrested stop_duration drugs_related_stop
# ...

# %%
data.stop_duration.value_counts()
# Out:
# 0-15 Min     39505
# 16-30 Min    10291
# 30+ Min       2395
# Name: stop_duration, dtype: int64

# %%
data['stop_duration'] = data['stop_duration'].map({'0-15 Min' : 7.5 , '16-30 Min' : 24 , '30+ Min' : 45} )

# %%
data
# Out:
#        stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0       1/2/2005      1:55             M          1985.0        20.0
# 1      1/18/2005      8:15             M          1965.0        40.0
# 2      1/23/2005     23:15             M          1972.0        33.0
# 3      2/20/2005     17:15             M          1986.0        19.0
# 4      3/14/2005     10:00             F          1984.0        21.0
# ...          ...       ...           ...             ...         ...
# 55736  1/18/2012     10:05             M          1952.0        60.0
# 55737  1/18/2012     10:12             M          1955.0        57.0
# 55738  1/18/2012     10:24             M          1983.0        29.0
# 55739  1/18/2012     10:36             F          1982.0        30.0
# 55740  1/18/2012     10:48             M          1986.0        26.0
#
#       driver_race                   violation_raw         violation  \
# 0           White                        Speeding          Speeding
# ...

# %%
data['stop_duration'].mean()
# Out:
# 12.474305914812899

# %% [markdown]
# **Question ( Groupby , Describe )**
#
# **5. Compare the age distribution for each violation.**

# %%
data.head()
# Out:
#    stop_date stop_time driver_gender  driver_age_raw  driver_age driver_race  \
# 0   1/2/2005      1:55             M          1985.0        20.0       White
# 1  1/18/2005      8:15             M          1965.0        40.0       White
# 2  1/23/2005     23:15             M          1972.0        33.0       White
# 3  2/20/2005     17:15             M          1986.0        19.0       White
# 4  3/14/2005     10:00             F          1984.0        21.0       White
#
#       violation_raw violation search_conducted search_type   stop_outcome  \
# 0          Speeding  Speeding            False         NaN       Citation
# 1          Speeding  Speeding            False         NaN       Citation
# 2          Speeding  Speeding            False         NaN       Citation
# 3  Call for Service     Other            False         NaN  Arrest Driver
# 4          Speeding  Speeding            False         NaN       Citation
#
#   is_arrested  stop_duration drugs_related_stop
# ...

# %%
data.groupby('violation').driver_age.describe()
# Out:
#                        count       mean        std   min   25%   50%   75%  \
# violation
# Equipment             4651.0  31.445066  11.254693  16.0  23.0  28.0  38.0
# Moving violation      9143.0  37.443837  13.366037  15.0  26.0  36.0  47.0
# Other                 3019.0  40.752236  12.641914  16.0  30.0  41.0  50.0
# Registration/plates   1921.0  32.412285  10.957909  16.0  24.0  29.0  40.0
# Speeding             33213.0  33.164875  12.561022  15.0  23.0  30.0  42.0
#
#                       max
# violation
# Equipment            81.0
# Moving violation     86.0
# Other                86.0
# Registration/plates  73.0
# Speeding             88.0
